# %% [markdown]
# <div class="b-1" style="padding: 90px 30px; background: white; display: flex; justify-content: center; align-items: center; flex-direction: column; position: relative;"><div class="b-2" style="display: flex; justify-content: center; flex-wrap: wrap; align-items: stretch; width: 620px; margin: 0 auto; padding: 10px 6px 6px;   max-width: 100%;"><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=00-00-0000-2" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/00-00-0000-2-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-31" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-31-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-13" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-13-300x.png"></a><a shape="rect" href="https://nanotheatre.github.io/vector-space.html?artefact=15-08-2020-4" style="border: 1px solid #ccc; margin: 0 2px 4px; background: #fff; display: flex; align-items: center; "><img style=" min-width: 300px; max-width: 300px;" src="https://nanotheatre.github.io/Vector-Space/300x/15-08-2020-4-300x.png"></a></div><div class="b-3" style="margin-top: 17px; display: flex; justify-content: space-around; font-size: 30px;"><a href="../../main/Polyptychs/Polyptych-04.ipynb" style="color: gray; margin: 0 30px;"><svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" fill="currentColor" class="bi bi-arrow-left-short" viewBox="0 0 16 16"><path fill-rule="evenodd" d="M12 8a.5.5 0 0 1-.5.5H5.707l2.147 2.146a.5.5 0 0 1-.708.708l-3-3a.5.5 0 0 1 0-.708l3-3a.5.5 0 1 1 .708.708L5.707 7.5H11.5a.5.5 0 0 1 .5.5"></path></svg></a><a href="../../main/Polyptychs/Polyptych-06.ipynb" style="color: gray; margin: 0 30px;"><svg xmlns="http://www.w3.org/2000/svg" width="30" height="30" fill="currentColor" class="bi bi-arrow-right-short" viewBox="0 0 16 16"><path fill-rule="evenodd" d="M4 8a.5.5 0 0 1 .5-.5h5.793L8.146 5.354a.5.5 0 1 1 .708-.708l3 3a.5.5 0 0 1 0 .708l-3 3a.5.5 0 0 1-.708-.708L10.293 8.5H4.5A.5.5 0 0 1 4 8"></path></svg></a></div></div>
